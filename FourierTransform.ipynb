# %% [markdown]
# # Fourier Transform in Python

# %% [markdown]
# ## Creating Sinusoidal Grating

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

wavelength = 200
y = np.sin(2 * np.pi * x / wavelength)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 1D Sine to 2D Sinusoidal Grating

# %% [markdown]
# using:
#
# ```python
# np.meshgrid()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X, Y = np.meshgrid(x, x)

wavelength = 200
grating = np.sin(2 * np.pi * X / wavelength)

plt.set_cmap("gray")
plt.imshow(grating)
plt.show()

# %%
wavelength = 100
grating = np.sin(2 * np.pi * X / wavelength)

plt.set_cmap("gray")
plt.imshow(grating)
plt.show()

# %%
wavelength = 100
grating = np.sin(2 * np.pi * Y / wavelength)

plt.set_cmap("gray")
plt.imshow(grating)
plt.show()

# %% [markdown]
# ## Change the Orientation

# %% [markdown]
# To transform the axes, use rotation concept.
#
# $x^{'} = cos(\theta) + y sin(\theta)$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X,Y = np.meshgrid(x, x)

wavelength = 200
angle = np.pi / 9
print(angle)
grating = np.sin(2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / wavelength)

plt.set_cmap("gray")
plt.imshow(grating)
plt.show()
# Out:
# 0.3490658503988659

# %% [markdown]
# ## The Fourier Transform

# %% [markdown]
# ### Representation of Sinusoidal Grating

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X, Y = np.meshgrid(x, x)

wavelength = 200
angle = 0
grating = np.sin(2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / wavelength)

plt.set_cmap("gray")
plt.subplot(121)
plt.imshow(grating)

# calculate  Fourier Transform of Grating
ft = np.fft.ifftshift(grating)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.subplot(122)
plt.imshow(abs(ft))
plt.xlim([480, 520])
plt.ylim([520, 480])
plt.tight_layout()
plt.show()

# %% [markdown]
# Double the frequency

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X, Y = np.meshgrid(x, x)

wavelength = 100
angle = 0
grating = np.sin(2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / wavelength)

plt.set_cmap("gray")
plt.subplot(121)
plt.imshow(grating)

# calculate  Fourier Transform of Grating
ft = np.fft.ifftshift(grating)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.subplot(122)
plt.imshow(abs(ft))
plt.xlim([480, 520])
plt.ylim([520, 480])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Rotating the sinusoidal grating

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X, Y = np.meshgrid(x, x)

wavelength = 100
angle = np.pi/9
grating = np.sin(2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / wavelength)

plt.set_cmap("gray")
plt.subplot(121)
plt.imshow(grating)

# calculate  Fourier Transform of Grating
ft = np.fft.ifftshift(grating)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.subplot(122)
plt.imshow(abs(ft))
plt.xlim([480, 520])
plt.ylim([520, 480])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Combining 2 Sinusoidal Gratings

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-500, 501, 1)
X, Y = np.meshgrid(x, x)
wavelength_1 = 200
angle_1 = 0
grating_1 = np.sin(
    2*np.pi*(X*np.cos(angle_1) + Y*np.sin(angle_1)) / wavelength_1
)
wavelength_2 = 100
angle_2 = np.pi/4
grating_2 = np.sin(
    2*np.pi*(X*np.cos(angle_2) + Y*np.sin(angle_2)) / wavelength_2
)
plt.set_cmap("gray")
plt.subplot(121)
plt.imshow(grating_1)
plt.subplot(122)
plt.imshow(grating_2)
plt.show()

gratings = grating_1 + grating_2
# Calculate Fourier transform of the sum of the two gratings
ft = np.fft.ifftshift(gratings)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.figure()
plt.subplot(121)
plt.imshow(gratings)
plt.subplot(122)
plt.imshow(abs(ft))
plt.xlim([480, 520])
plt.ylim([520, 480])  # Note, order is reversed for y
plt.show()

# %% [markdown]
# ### Adding More Sinusoidal Gratings

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)
X, Y = np.meshgrid(x, x)

amplitudes = 0.5, 0.25, 1, 0.75, 1
wavelengths = 200, 100, 250, 300, 60

angles = 0, np.pi / 4, np.pi / 9, np.pi / 2, np.pi / 12
gratings = np.zeros(X.shape)
for amp, w_len, angle in zip(amplitudes, wavelengths, angles):
    gratings += amp * np.sin(
        2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / w_len
    )
# Calculate Fourier transform of the sum of the gratings
ft = np.fft.ifftshift(gratings)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)
plt.set_cmap("gray")
plt.subplot(121)
plt.imshow(gratings)
plt.subplot(122)
plt.imshow(abs(ft))
plt.xlim([480, 520])
plt.ylim([520, 480])  # Note, order is reversed for y
plt.show()

# %% [markdown]
# ### Adding Constant Term to Final Image

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)
X, Y = np.meshgrid(x, x)

amplitudes = 0.5, 0.25, 1, 0.75, 1
wavelengths = 200, 100, 250, 300, 60
angles = 0, np.pi / 4, np.pi / 9, np.pi / 2, np.pi / 12
gratings = np.zeros(X.shape)

for amp, w_len, angle in zip(amplitudes, wavelengths, angles):
    gratings += amp * np.sin(
        2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / w_len
    )
    
# Add a constant term to represent the background of image
gratings += 1.25

# Calculate Fourier transform of the sum of the gratings
ft = np.fft.ifftshift(gratings)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.set_cmap("gray")
plt.subplot(121)
plt.imshow(gratings)
plt.subplot(122)
plt.imshow(abs(ft))
plt.xlim([480, 520])
plt.ylim([520, 480])  # Note, order is reversed for y
plt.show()

# %% [markdown]
# **Note**: the center of Fourier Transform represent the constant background of the image

# %% [markdown]
# ## Calculating 2D Fourier Transform of an Image

# %% [markdown]
# ### Reading the Image and Converting to Grayscale

# %%
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)
print(image.shape)

plt.set_cmap("gray")

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# (301, 301)

# %% [markdown]
# ### Calculating 2D Fourier Transform

# %%
import numpy as np
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)

image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)
print(image.shape)

plt.set_cmap("gray")

ft = calculate_2dft(image)

plt.subplot(121)
plt.imshow(image)
plt.axis("off")
plt.subplot(122)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.show()
# Out:
# (301, 301)

# %% [markdown]
# **Note**:
#
# 1. One sinusoidal grating is representated as a pair of dots with the spesific frequency, amplitude, orientation, and phase.
# 2. A pair of dots will have same distance from the center of Fourier Transform.
# 3. The further away the dots from the center, the higher frequency.
# 4. The brighter the dots means higher amplitude.
# 5. The orientation of each pair of dots in relation to the center represent the orientation of the gratings.
# 6. The phase is also encoded in the Fourier transform matrix.

# %% [markdown]
# ## Reverse Engineering the Fourier Transform Data

# %% [markdown]
# FFT algorithm can decomposes the image into thousand of components. Each component is **SINUSOIDAL GRATING**.
#
# **INTUITION**:
# If we can take any matching pair of dots in Fourier Transform, we can extract all the parameters for recreating the sinusoidal grating.

# %% [markdown]
# ### The Inverse Fourier Transform

# %% [markdown]
# **INTUITION**:
# Doing Fourier Transform of the Fourier Transform itself = Original image
#
# For doing this, we can use:
#
# ```python
# np.fft.ifft2()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-500, 501, 1)

X, Y = np.meshgrid(x, x)

wavelength = 100
angle = np.pi/9
grating = np.sin(2*np.pi*(X*np.cos(angle) + Y*np.sin(angle)) / wavelength)

plt.set_cmap("gray")

plt.subplot(131)
plt.imshow(grating)
plt.axis("off")

# calculate  Fourier Transform of Grating
ft = np.fft.ifftshift(grating)
ft = np.fft.fft2(ft)
ft = np.fft.fftshift(ft)

plt.subplot(132)
plt.imshow(abs(ft))
plt.axis("off")
plt.xlim([480, 520])
plt.ylim([520, 480])

# Calculate the inverse Fourier Transform of the Fourier Transform
ift = np.fft.ifftshift(ft)
ift = np.fft.ifft2(ift)
ift = np.fft.fftshift(ift)
ift = ift.real # take only the real part

plt.subplot(133)
plt.imshow(ift)
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Finding All the Pairs of Points in the 2D Fourier Tranform

# %%
import numpy as np
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)

def calculate_2dift(input):
    ift = np.fft.ifftshift(input)
    ift = np.fft.ifft2(ift)
    ift = np.fft.fftshift(ft)
    return ift.real

image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)
print(image.shape)

# Array dimensions (square) and center pixel
array_size = len(image)
center = int((array_size - 1) / 2)

# Get all coordinate pairs in the left half of the array
# Also get the center of the array
coords_left_half = (
    (x, y) for x in range(array_size) for y in range(center+1)
)

plt.set_cmap("gray")

ft = calculate_2dft(image)

plt.subplot(121)
plt.imshow(image)
plt.axis("off")
plt.subplot(122)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.show()
# Out:
# (301, 301)

# %% [markdown]
# ### Sorting the Coordinates in Order of Distance from The Center

# %% [markdown]
# Intention:
#
# Starting to reconstruct image with the gratings with the lowest frequencies first to higher frequencies

# %%
import numpy as np
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)

def calculate_2dift(input):
    ift = np.fft.ifftshift(input)
    ift = np.fft.ifft2(ift)
    ift = np.fft.fftshift(ft)
    return ift.real

def calculate_distance_from_center(coords, center):
    return np.sqrt(
        (coords[0] - center) ** 2 + (coords[1] - center)
    )

image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)
print(image.shape)

# Array dimensions (square) and center pixel
array_size = len(image)
center = int((array_size - 1) / 2)

# Get all coordinate pairs in the left half of the array
# Also get the center of the array
coords_left_half = sorted(
    coords_left_half,
    key=lambda x: calculate_distance_from_center(x, center)
)

plt.set_cmap("gray")

ft = calculate_2dft(image)

plt.subplot(121)
plt.imshow(image)
plt.axis("off")
plt.subplot(122)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.show()
# Out:
# (301, 301)

# %% [markdown]
# ### Finding the Second Symmetrical Point of Each Pair

# %%
import numpy as np
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)

def calculate_2dift(input):
    ift = np.fft.ifftshift(input)
    ift = np.fft.ifft2(ift)
    ift = np.fft.fftshift(ift)
    return ift.real

def calculate_distance_from_center(coords, center):
    return np.sqrt(
        (coords[0] - center) ** 2 + (coords[1] - center) ** 2
    )

def find_symmetric_coordinates(coords, center):
    return (center + (center - coords[0]),
            center + (center - coords[1]))

image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)
print(image.shape)

# Array dimensions (square) and center pixel
array_size = len(image)
center = int((array_size - 1) / 2)

# Get all coordinate pairs in the left half of the array
# Also get the center of the array
coords_left_half = sorted(
    coords_left_half,
    key=lambda x: calculate_distance_from_center(x, center)
)

plt.set_cmap("gray")

ft = calculate_2dft(image)

plt.subplot(121)
plt.imshow(image)
plt.axis("off")
plt.subplot(122)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.show()
# Out:
# (301, 301)
# /var/folders/sy/mr93m1ln7tq1hc3ghdqzwth40000gn/T/ipykernel_31338/661575297.py:18: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(

# %% [markdown]
# ### Reconstructing 2D Fourier Transform to Reconstruct the Image

# %% [markdown]
# 1. Create an empty array, full of zeros, ready to be used for each pair of points.
# 2. Iterate through the coordinates in ``coords_left_half``. For each point, find its corresponding point on the right-hand side to complete the pair.
# 3. For each pair of points, copy the values of those points from the Fourier transform into the empty array.
# 4. Calculate the inverse Forier Transform of the array containing the pair of points. This gives the sinusoidal gratings represented by these points.

# %%
import numpy as np
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)

def calculate_2dift(input):
    ift = np.fft.ifftshift(input)
    ift = np.fft.ifft2(ift)
    ift = np.fft.fftshift(ift)
    return ift.real

def calculate_distance_from_center(coords, center):
    return np.sqrt(
        (coords[0] - center) ** 2 + (coords[1] - center) ** 2
    )

def find_symmetric_coordinates(coords, center):
    return (center + (center - coords[0]),
            center + (center - coords[1]))

def display_plots(individual_grating, reconstruction, idx):
    plt.subplot(121)
    plt.imshow(individual_grating)
    plt.axis("off")
    plt.subplot(122)
    plt.imshow(reconstruction)
    plt.axis("off")
    plt.suptitle(f"Terms: {idx}")
    plt.pause(0.01)

image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)
print(image.shape)

# Array dimensions (square) and center pixel
array_size = len(image)
center = int((array_size - 1) / 2)

# Get all coordinate pairs in the left half of the array
# Also get the center of the array
coords_left_half = sorted(
    coords_left_half,
    key=lambda x: calculate_distance_from_center(x, center)
)

plt.set_cmap("gray")

ft = calculate_2dft(image)

# show grayscale image and its Fourier Transform
plt.subplot(121)
plt.imshow(image)
plt.axis("off")
plt.subplot(122)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.pause(2)

# Reconstruct image
fig = plt.figure()

# Step 1
rec_image = np.zeros(image.shape)
individual_grating = np.zeros(
    image.shape, dtype="complex"
)
idx = 0

# Step 2
for coords in coords_left_half:
    # Central column: only include if points in top half of the central column
    if not (coords[1] == center and coords[0] > center):
        idx += 1
        symm_coords = find_symmetric_coordinates(
            coords, center
        )

        # Step 3
        individual_grating[coords] = ft[coords]
        individual_grating[symm_coords] = ft[symm_coords]

        # Step 4
        rec_grating = calculate_2dift(individual_grating)
        rec_image += rec_grating
        individual_grating[coords] = 0
        individual_grating[symm_coords] = 0

        display_plots(rec_grating, rec_image, idx)

plt.show()

# %% [markdown]
# ### Speeding up the Animation

# %%
# fourier_synthesis.py

import numpy as np
import matplotlib.pyplot as plt

image_filename = "./FFTImages/Earth.png"

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)

def calculate_2dift(input):
    ift = np.fft.ifftshift(input)
    ift = np.fft.ifft2(ift)
    ift = np.fft.fftshift(ift)
    return ift.real

def calculate_distance_from_center(coords, center):
    # Distance from center is √(x^2 + y^2)
    return np.sqrt(
        (coords[0] - center) ** 2 + (coords[1] - center) ** 2
    )

def find_symmetric_coordinates(coords, center):
    return (center + (center - coords[0]),
            center + (center - coords[1]))

def display_plots(individual_grating, reconstruction, idx):
    plt.subplot(121)
    plt.imshow(individual_grating)
    plt.axis("off")
    plt.subplot(122)
    plt.imshow(reconstruction)
    plt.axis("off")
    plt.suptitle(f"Terms: {idx}")
    plt.pause(0.01)

# Read and process image
image = plt.imread(image_filename)
image = image[:, :, :3].mean(axis=2)  # Convert to grayscale

# Array dimensions (array is square) and center pixel
array_size = len(image)
center = int((array_size - 1) / 2)

# Get all coordinate pairs in the left half of the array,
# including the column at the center of the array (which
# includes the center pixel)
coords_left_half = (
    (x, y) for x in range(array_size) for y in range(center+1)
)

# Sort points based on distance from center
coords_left_half = sorted(
    coords_left_half,
    key=lambda x: calculate_distance_from_center(x, center)
)

plt.set_cmap("gray")

ft = calculate_2dft(image)

# Show grayscale image and its Fourier transform
plt.subplot(121)
plt.imshow(image)
plt.axis("off")
plt.subplot(122)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.pause(2)

# Reconstruct image
fig = plt.figure()
# Step 1
# Set up empty arrays for final image and
# individual gratings
rec_image = np.zeros(image.shape)
individual_grating = np.zeros(
    image.shape, dtype="complex"
)
idx = 0

# All steps are displayed until display_all_until value
display_all_until = 200
# After this, skip which steps to display using the
# display_step value
display_step = 10
# Work out index of next step to display
next_display = display_all_until + display_step

# Step 2
for coords in coords_left_half:
    # Central column: only include if points in top half of
    # the central column
    if not (coords[1] == center and coords[0] > center):
        idx += 1
        symm_coords = find_symmetric_coordinates(
            coords, center
        )
        # Step 3
        # Copy values from Fourier transform into
        # individual_grating for the pair of points in
        # current iteration
        individual_grating[coords] = ft[coords]
        individual_grating[symm_coords] = ft[symm_coords]

        # Step 4
        # Calculate inverse Fourier transform to give the
        # reconstructed grating. Add this reconstructed
        # grating to the reconstructed image
        rec_grating = calculate_2dift(individual_grating)
        rec_image += rec_grating

        # Clear individual_grating array, ready for
        # next iteration
        individual_grating[coords] = 0
        individual_grating[symm_coords] = 0

        # Don't display every step
        if idx < display_all_until or idx == next_display:
            if idx > display_all_until:
                next_display += display_step
                # Accelerate animation the further the
                # iteration runs by increasing
                # display_step
                display_step += 10
            display_plots(rec_grating, rec_image, idx)

plt.show()
